# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Final_Year_Project/Result/PD_Result/New_PD_Result/')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import glob
import os

# Set the path to the folder containing the CSV files
folder_path = '/content/drive/MyDrive/Final_Year_Project/Result/PD_Result/New_PD_Result/'

# Print the folder path to check for errors
print("folder path:", folder_path)

# Get a list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# Print the list of CSV files found
print("CSV files found:", csv_files)

# Create an empty list to store the dataframes
dfs = []

# Loop through each CSV file, read it into a dataframe, and append it to the list
for csv_file in csv_files:
    # Use the 'python' engine to handle potential parsing issues
    df = pd.read_csv(csv_file, engine='python')
    dfs.append(df)

# Concatenate all the dataframes in the list into a single dataframe
combined_df = pd.concat(dfs, ignore_index=True)

# Export the combined dataframe to a CSV file
combined_df.to_csv('combined_dataset_PDNew.csv', index=False)
# Out:
# folder path: /content/drive/MyDrive/Final_Year_Project/Result/PD_Result/New_PD_Result/
# ...

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/Final_Year_Project/Result/PD_Result/New_PD_Result/combined_dataset_PDNew.csv')
df_2 = pd.read_csv('/content/drive/MyDrive/Final_Year_Project/Result/HC_Result/combined_dataset_HC2.csv')
combined_dataset_HC_PD = pd.concat([df_2, df_1], ignore_index=True)
combined_dataset_HC_PD.to_csv('combined_dataset_HC_PD.csv', index=False)
# Out:
# <ipython-input-5-241322045079>:2: DtypeWarning: Columns (225,1385) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv('/content/drive/MyDrive/Final_Year_Project/Result/HC_Result/combined_dataset_HC2.csv')
